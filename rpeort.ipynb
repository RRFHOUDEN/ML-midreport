# %% [markdown]
# # problem1

# %%
# ML課題
# (1)
import numpy as np

# %%
def function(xx, ww):
    # ww is numpy matrix
    return 2 * (ww.T * xx > 0) - 1

# %%
def J(xx, y, ww, lam):
    res = 0
    for i in range(n):
        res = np.log(1+np.exp(-y[i]*ww.T*xx[i]))
    res += lam * ww.T * ww
    return res

# %%
# dataset
def make_dataset(n):
    x = 3 * (np.random.rand(n,4) - 0.5)
    y = (2 * x[:,0] - 1 * x[:,2] + 0.5 + 0.5*np.random.randn(1,n)) > 0
    y = 2 * y - 1
    y = y.T
    return x, y

# %%
# optimize algorithm1
def gradient(xx, y, ww, lam):
    res = 0
    for i in range(n):
        res += -y[i]*xx[i]*np.exp(-y[i]*ww.T*xx[i]) / (1+np.exp(-y[i]*ww.T*xx[i]))
    res += 2*lam*ww
    return res


# optimize algorithm2
def newton(xx, y, ww, lam):
    res = 0
    for i in range(n):
        tmp = -y[i]*xx[i]*np.exp(-y[i]*ww.T*xx[i])
#         print(tmp)
        tmp *= -y[i]**2*xx[i].T*xx[i]*np.exp(-y[i]*ww.T*xx[i])
        tmp *= (1+np.exp(-y[i]*ww.T*xx[i]))
        
        tmp2 = -y[i]*xx[i]*np.exp(-y[i]*ww.T*xx[i])
        tmp2 *= (1+np.exp(-y[i]*ww.T*xx[i]))
        tmp2 *= -y[i]*xx[i]*np.exp(-y[i]*ww.T*xx[i])
        
        tmp3 = (1+np.exp(-y[i]*ww.T*xx[i]))**2
        
        res += (tmp-tmp2) / tmp3
        
    res += 2*lam
    return res


def optimizer(num, xx, y, ww, lam, eta):
    if num == 0:
        grad = gradient(xx, y, ww, lam)
    if num == 1:
        grad = newton(xx, y, ww, lam)
    ww = ww - eta*grad
    return ww

# %%
n = 200
xx, y = make_dataset(n)
np.random.seed(1234)

ww = np.random.rand(4)
lam = 0.001
eta = 0.01
for i in range(100):
    ww = optimizer(0, xx, y, ww, lam, eta)
    print(2, J(xx, y, ww, lam))
# Out:
# 2 [0.83750056 0.50391931 0.70649853 0.78807093]
# 2 [0.91332729 0.52850405 0.57309019 0.72681984]
# 2 [0.96949053 0.543581   0.50200137 0.68825361]
# 2 [1.01360777 0.55260508 0.46175481 0.66391957]
# 2 [1.04964406 0.55793247 0.43785429 0.64839699]
# 2 [1.07988122 0.56105296 0.42318637 0.63838375]
# 2 [1.10574833 0.56287261 0.41398641 0.63186634]
# 2 [1.12820049 0.56393095 0.40813321 0.62759648]
# 2 [1.14790891 0.5645456  0.40437449 0.62478628]
# 2 [1.16536426 0.56490225 0.40194609 0.62293094]
# 2 [1.18093683 0.5651091  0.40037095 0.62170342]
# 2 [1.19491336 0.56522904 0.39934661 0.62089011]
# 2 [1.35276142 0.56539443 0.39742554 0.61928504]
# 2 [1.35322888 0.56539443 0.39742554 0.61928504]
# 2 [1.3536677  0.56539443 0.39742554 0.61928504]
# 2 [1.35407966 0.56539443 0.39742554 0.61928504]
# 2 [1.35446645 0.56539443 0.39742554 0.61928504]
# 2 [1.35482962 0.56539443 0.39742554 0.61928504]
# 2 [1.35517064 0.56539443 0.39742554 0.61928504]
# 2 [1.35549088 0.56539443 0.39742554 0.61928504]
# 2 [1.35579162 0.56539443 0.39742554 0.61928504]
# 2 [1.35607406 0.56539443 0.39742554 0.61928504]
# 2 [1.35633933 0.56539443 0.39742554 0.61928504]
# 2 [1.35658849 0.56539443 0.39742554 0.61928504]
# 2 [1.35682252 0.56539443 0.39742554 0.61928504]
# 2 [1.35704235 0.56539443 0.39742554 0.61928504]
# 2 [1.35724886 0.56539443 0.39742554 0.61928504]
# 2 [1.35744285 0.56539443 0.39742554 0.61928504]
# 2 [1.35762509 0.56539443 0.39742554 0.61928504]
# 2 [1.3577963  0.56539443 0.39742554 0.61928504]
# 2 [1.35795715 0.56539443 0.39742554 0.61928504]
# 2 [1.35810827 0.56539443 0.39742554 0.61928504]
# 2 [1.35825026 0.56539443 0.39742554 0.61928504]
# 2 [1.35838366 0.56539443 0.39742554 0.61928504]
# 2 [1.35850901 0.56539443 0.39742554 0.61928504]
# 2 [1.35862678 0.56539443 0.39742554 0.61928504]
# 2 [1.35873745 0.56539443 0.39742554 0.61928504]
# 2 [1.35884143 0.56539443 0.39742554 0.61928504]
# 2 [1.35893914 0.56539443 0.39742554 0.61928504]
# 2 [1.35903096 0.56539443 0.39742554 0.61928504]
# 2 [1.35911724 0.56539443 0.39742554 0.61928504]
# 2 [1.35919832 0.56539443 0.39742554 0.61928504]
# 2 [1.35927451 0.56539443 0.39742554 0.61928504]
# 2 [1.35934611 0.56539443 0.39742554 0.61928504]
# 2 [1.35941339 0.56539443 0.39742554 0.61928504]
# 2 [1.35947662 0.56539443 0.39742554 0.61928504]
# 2 [1.35953604 0.56539443 0.39742554 0.61928504]
# 2 [1.35959189 0.56539443 0.39742554 0.61928504]
# 2 [1.35964437 0.56539443 0.39742554 0.61928504]
# 2 [1.35969369 0.56539443 0.39742554 0.61928504]
# 2 [1.35974004 0.56539443 0.39742554 0.61928504]
# 2 [1.3597836  0.56539443 0.39742554 0.61928504]
# 2 [1.35982454 0.56539443 0.39742554 0.61928504]
# 2 [1.35986302 0.56539443 0.39742554 0.61928504]
# 2 [1.35989918 0.56539443 0.39742554 0.61928504]

# %% [markdown]
# # problem2

# %%
import numpy as np

# %%
def problem2_loss_function(AA, w, mm, lam):
    return (ww-mm).Taa(ww-mm) + lam*np.sum(ww)
